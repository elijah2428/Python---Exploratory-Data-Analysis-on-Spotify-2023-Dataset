# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
df = pd.read_csv('spotify-2023.csv',encoding='latin-1')
df
# Out:
#                                             track_name  \
# 0                  Seven (feat. Latto) (Explicit Ver.)
# 1                                                 LALA
# 2                                              vampire
# 3                                         Cruel Summer
# 4                                       WHERE SHE GOES
# 5                                             Sprinter
# 6                                      Ella Baila Sola
# 7                                             Columbia
# 8                                             fukumean
# 9                                      La Bebe - Remix
# 10                                           un x100to
# 11                                           Super Shy
# 12                                             Flowers
# 13                                            Daylight
# 14                                           As It Was
# 15                                           Kill Bill
# 16                                   Cupid - Twin Ver.
# 17   What Was I Made For? [From The Motion Picture ...
# 18                                          Classy 101
# 19                                          Like Crazy
# 20                                           LADY GAGA
# 21   I Can See You (Taylorï¿½ï¿½ï¿½s Version) (From...
# 22                                    I Wanna Be Yours
# 23            Peso Pluma: Bzrp Music Sessions, Vol. 55
# 24   Popular (with Playboi Carti & Madonna) - The I...
# 25                                         SABOR FRESA
# 26                       Calm Down (with Selena Gomez)
# 27                                        MOJABI GHOST
# 28                                          Last Night
# 29             Dance The Night (From Barbie The Album)
# 30                                                Rush
# 31                                               TULUM
# 32                                            Creepin'
# 33                                           Anti-Hero
# 34                                                 TQG
# 35                                     Los del Espacio
# 36                      Frï¿½ï¿½gil (feat. Grupo Front
# 37                                         Blank Space
# 38                                               Style
# 39                                                 TQM
# 40                                             El Azul
# 41       Sunflower - Spider-Man: Into the Spider-Verse
# 42                                     I'm Good (Blue)
# 43                                       See You Again
# 44    Barbie World (with Aqua) [From Barbie The Album]
# 45                                     Angels Like You
# 46                                     I Ain't Worried
# 47                                         Die For You
# 48                                             Starboy
# 49                                 Die For You - Remix
# 50                                            El Cielo
# 51                                  Baby Don't Hurt Me
# 52                                            AMARGURA
# 53                        (It Goes Like) Nanana - Edit
# 54                                        Another Love
# 55                                     Blinding Lights
# 56                                           Moonlight
# 57                                          La Bachata
# 58                                                 S91
# 59                                            cardigan
# 60                                              Tï¿½ï¿
# 61                                  Boy's a liar Pt. 2
# 62             Left and Right (Feat. Jung Kook of BTS)
# 63                                                BESO
# 64                                             Hey Mor
# 65                                              Yellow
# 66                                               Karma
# 67                                              People
# 68                                           Overdrive
# 69                        Enchanted (Taylor's Version)
# 70                                          BABY HELLO
# 71                                          Heat Waves
# 72                                         golden hour
# 73                                     Sweater Weather
# 74               Quevedo: Bzrp Music Sessions, Vol. 52
# 75                                        Viva La Vida
# 76                                        Here With Me
# 77                           Unholy (feat. Kim Petras)
# 78                                          Yandel 150
# 79                                     CORAZï¿½ï¿½N VA
# 80                                             Riptide
# 81   Until I Found You (with Em Beihold) - Em Beiho...
# 82                                   Novidade na ï¿½ï¿
# 83                 Back To December (Taylor's Version)
# 84                           STAY (with Justin Bieber)
# 85                                         El Merengue
# 86                                   Someone You Loved
# 87                                     Me Porto Bonito
# 88                                              Makeba
# 89                                  MONTAGEM - FR PUNK
# 90                                            Fast Car
# 91                           What It Is (Solo Version)
# 92                                         Coco Chanel
# 93                                    Donï¿½ï¿½ï¿½t Bl
# 94                                      Still With You
# 95                         All My Life (feat. J. Cole)
# 96                                   Say Yes To Heaven
# 97                                              Snooze
# 98                                  Summertime Sadness
# 99                                            Take Two
# 100                                              Lover
# 101  Too Many Nights (feat. Don Toliver & with Future)
# 102                                           Chemical
# 103                                        Mockingbird
# 104                                          New Jeans
# 105                                       Primera Cita
# 106                            Cold Heart - PNAU Remix
# 107                                         Dandelions
# 108                                              Bones
# 109                               Set Fire to the Rain
# 110                                        Money Trees
# 111                                  Tak Segampang Itu
# 112                                            LAGUNAS
# 113                            Mine (Taylor's Version)
# 114                  Everybody Wants To Rule The World
# 115                                     No Role Modelz
# 116                                             Tattoo
# 117                                           Rara Vez
# 118                                          VAGABUNDO
# 119                                             august
# 120                                               LUNA
# 121                      Miracle (with Ellie Goulding)
# 122                                           Nonsense
# 123                                        Que Vuelvas
# 124                                     Por las Noches
# 125                           Feliz Cumpleaï¿½ï¿½os Fe
# 126                   Can't Hold Us (feat. Ray Dalton)
# 127                                   Watermelon Sugar
# 128                               lovely - Bonus Track
# 129       Rauw Alejandro: Bzrp Music Sessions, Vol. 56
# 130                                          Queencard
# 131                                                OMG
# 132                                              Radio
# 133              Shakira: Bzrp Music Sessions, Vol. 53
# 134                                                505
# 135  Calling (Spider-Man: Across the Spider-Verse) ...
# 136            Trance (with Travis Scott & Young Thug)
# 137        Tere Vaaste (From "Zara Hatke Zara Bachke")
# 138                                            Perfect
# 139                                  Romantic Homicide
# 140                                           Believer
# 141                                      Novo Balanï¿½
# 142                        Gol Bolinha, Gol Quadrado 2
# 143                                         Without Me
# 144                                              QUEMA
# 145                                 Stargirl Interlude
# 146                                      Ojitos Lindos
# 147                             Somewhere Only We Know
# 148                                         Those Eyes
# 149                             El Gordo Trae El Mando
# 150                                     Mi Bello Angel
# 151                                                Bye
# 152                                       Danza Kuduro
# 153                                       Nosso Quadro
# 154                               Locked Out Of Heaven
# 155                            Un Finde | CROSSOVER #2
# 156                      Jimmy Cooks (feat. 21 Savage)
# 157                                     Counting Stars
# 158                                              Ghost
# 159                                Under The Influence
# 160                                                PRC
# 161                                           Gasolina
# 162                                          One Dance
# 163                                          Enchanted
# 164                                    Save Your Tears
# 165                                         Sure Thing
# 166            Every Breath You Take - Remastered 2003
# 167                                   The Night We Met
# 168                                      We Found Love
# 169                                When I Was Your Man
# 170                                 Let Me Down Slowly
# 171  Am I Dreaming (Metro Boomin & A$AP Rocky, Roisee)
# 172                                   Do I Wanna Know?
# 173                                             Demons
# 174                                       ýýýýýýýýýýýý
# 175                                           Reminder
# 176                                       Shake It Off
# 177           Why'd You Only Call Me When You're High?
# 178                                               SNAP
# 179                                       Shape of You
# 180                                      Night Changes
# 181                                      Fin de Semana
# 182                                              Creep
# 183                                      Car's Outside
# 184                                         Apocalypse
# 185                                            Cheques
# 186                                       Pink + White
# 187                                            Circles
# 188                               Just The Way You Are
# 189                                  Take Me To Church
# 190                                          Bebe Dame
# 191            You Belong With Me (Taylorï¿½ï¿½ï¿½s Ve
# 192                                  Titi Me Preguntï¿
# 193             Better Than Revenge (Taylor's Version)
# 194                            Shut up My Moms Calling
# 195                       Have You Ever Seen The Rain?
# 196                                      Es un Secreto
# 197                                    POLARIS - Remix
# 198                                              Ditto
# 199                                         Take On Me
# 200  Annihilate (Spider-Man: Across the Spider-Vers...
# 201  Angel Pt 1 (feat. Jimin of BTS, JVKE & Muni Long)
# 202                                         Acrï¿½ï¿½s
# 203                                                AMG
# 204  Phir Aur Kya Chahiye (From "Zara Hatke Zara Ba...
# 205                                            S-Class
# 206                                     Hits Different
# 207                                             Chanel
# 208  Self Love (Spider-Man: Across the Spider-Verse...
# 209                                         Area Codes
# 210                                           Abcdario
# 211                                           Obsessed
# 212                                   Piï¿½ï¿½man Deï¿
# 213                                             FLOWER
# 214  All The Way Live (Spider-Man: Across the Spide...
# 215                                        Eyes Closed
# 216                                          Escapism.
# 217                                           La Jumpa
# 218                            Karma (feat. Ice Spice)
# 219  Superhero (Heroes & Villains) [with Future & C...
# 220                                         Las Morras
# 221                             CHORRITO PA LAS ANIMAS
# 222                                      Ch y la Pizza
# 223        Snow On The Beach (feat. More Lana Del Rey)
# 224                                            Players
# 225                                            Bite Me
# 226                  Stand By Me (feat. Morgan Wallen)
# 227                                             Normal
# 228           Hummingbird (Metro Boomin & James Blake)
# 229                         Seu Brilho Sumiu - Ao Vivo
# 230                                          Bad Habit
# 231                                            CUFF IT
# 232      Lilith (feat. SUGA of BTS) (Diablo IV Anthem)
# 233                                                 69
# 234                                       Niï¿½ï¿½a Bo
# 235                                    Search & Rescue
# 236       AMERICA HAS A PROBLEM (feat. Kendrick Lamar)
# 237                                      Lavender Haze
# 238  Link Up (Metro Boomin & Don Toliver, Wizkid fe...
# 239                                             Efecto
# 240                             Erro Gostoso - Ao Vivo
# 241                                             Cupido
# 242                                    Just Wanna Rock
# 243                                        Unstoppable
# 244                                  Until I Found You
# 245                                          Rich Flex
# 246                                         Easy On Me
# 247                                      Cartï¿½ï¿½o B
# 248                     Danger (Spider) (Offset & JID)
# 249                                 Oi Balde - Ao Vivo
# 250                                The Real Slim Shady
# 251                                             MERCHO
# 252                                   The Color Violet
# 253                                      Glimpse of Us
# 254                                       Mejor Que Yo
# 255                                           Curtains
# 256                    UNFORGIVEN (feat. Nile Rodgers)
# 257                                            Haegeum
# 258           Conexï¿½ï¿½es de Mï¿½ï¿½fia (feat. Rich
# 259                          MIENTRAS ME CURO DEL CORA
# 260                                Never Felt So Alone
# 261                                      X SI VOLVEMOS
# 262                                           ceilings
# 263                                              Cupid
# 264                                               I AM
# 265  Cupid ï¿½ï¿½ï¿½ Twin Ver. (FIFTY FIFTY) ï¿½ï¿½...
# 266                                       Shorty Party
# 267                                              Super
# 268                                        Slut Me Out
# 269                       Double Fantasy (with Future)
# 270                  All Of The Girls You Loved Before
# 271                                           PROVENZA
# 272                  Princess Diana (with Nicki Minaj)
# 273                                          Di Que Si
# 274                                            Shivers
# 275                                 Igualito a Mi Apï¿
# 276                  Shoong! (feat. LISA of BLACKPINK)
# 277                                             Komang
# 278                                          DESPECHï¿
# 279                                      Made You Look
# 280            Watch This - ARIZONATEARS Pluggnb Remix
# 281                                           No Se Va
# 282                                            Punto G
# 283                                        Lovers Rock
# 284                                      METAMORPHOSIS
# 285                                         Mami Chula
# 286                                           En Paris
# 287                                   Set Me Free Pt.2
# 288                                  I Was Never There
# 289           Don't ever say love me (feat. RM of BTS)
# 290                                          Shut Down
# 291                                      Gato de Noche
# 292                                   Call Out My Name
# 293                       Like Crazy (English Version)
# 294                                        Rosa Pastel
# 295                                            Sunroof
# 296                 Lose Yourself - Soundtrack Version
# 297                                           Superman
# 298                                  Mas Rica Que Ayer
# 299                             People Pt.2 (feat. IU)
# 300                                    REMIX EXCLUSIVO
# 301            Arcï¿½ï¿½ngel: Bzrp Music Sessions, Vol
# 302                                           DOGTOOTH
# 303                                              10:35
# 304                                    SORRY NOT SORRY
# 305                                              HAPPY
# 306                                            La Bebe
# 307                               I Know - PR1SVX Edit
# 308                                 Late Night Talking
# 309                                              Leï¿½
# 310       Save Your Tears (with Ariana Grande) (Remix)
# 311                            Something in the Orange
# 312                                               VOID
# 313                       Dijeron Que No La Iba Lograr
# 314                                      Midnight Rain
# 315                                If We Ever Broke Up
# 316                                          You Proof
# 317                                        LA INOCENTE
# 318                                   Malas Decisiones
# 319                                  Murder In My Mind
# 320                                 Gangsta's Paradise
# 321                                              CAIRO
# 322                                      I Love You So
# 323                                           Dark Red
# 324                               Say You Won't Let Go
# 325                                          The Hills
# 326                                     Heart To Heart
# 327         Peaches (from The Super Mario Bros. Movie)
# 328                                   Marisola - Remix
# 329                                             LOKERA
# 330                                                Low
# 331                                               Numb
# 332                         Tormenta (feat. Bad Bunny)
# 333                       on the street (with J. Cole)
# 334                                One Thing At A Time
# 335                                           Miss You
# 336                                  Ainï¿½ï¿½ï¿½t Tha
# 337                                 Thinkinï¿½ï¿½ï¿½ B
# 338     Private Landing (feat. Justin Bieber & Future)
# 339                                  Everything I Love
# 340                                             Heaven
# 341                                             LET GO
# 342                                               Sial
# 343                                   I Wrote The Book
# 344                      Apna Bana Le (From "Bhediya")
# 345                                   SPIT IN MY FACE!
# 346                                  PLAYA DEL INGLï¿½
# 347                 Man Made A Bar (feat. Eric Church)
# 348                                 Red Ruby Da Sleeze
# 349                                    Kahani Suno 2.0
# 350                                     Nobody Gets Me
# 351                                           PERO Tï¿
# 352                                           Hype Boy
# 353                                        Bloody Mary
# 354                                         Monotonï¿½
# 355                                       ýýý98 Braves
# 356                                              WANDA
# 357                            Thought You Should Know
# 358                                         In The End
# 359                                     Zona De Perigo
# 360                                          Lovezinho
# 361        I Like You (A Happier Song) (with Doja Cat)
# 362                                           Neverita
# 363                                       Vista Al Mar
# 364                               Sem Alianï¿½ï¿½a no
# 365  Enemy (with JID) - from the series Arcane Leag...
# 366                                            Revenge
# 367                              Bombonzinho - Ao Vivo
# 368                                        LA CANCIï¿½
# 369                                       Quï¿½ï¿½ Ago
# 370                                         Love Again
# 371                                        After Hours
# 372                                    About Damn Time
# 373                        Born With A Beer In My Hand
# 374                              ýýýýýýýýýýýýýýýýýýýýý
# 375                                        Besos Moja2
# 376                                     Maan Meri Jaan
# 377                                        Moscow Mule
# 378                                        My Universe
# 379                                 Devil Donï¿½ï¿½ï¿½
# 380                                              LLYLM
# 381                       I'm Not Here To Make Friends
# 382                                          TRUSTFALL
# 383                                        ANTIFRAGILE
# 384                                       Boy's a liar
# 385                          VIBE (feat. Jimin of BTS)
# 386                                              Shirt
# 387  Lift Me Up - From Black Panther: Wakanda Forev...
# 388     STAR WALKIN' (League of Legends Worlds Anthem)
# 389                                   Sex, Drugs, Etc.
# 390                        Boy With Luv (feat. Halsey)
# 391                                       Hey, Mickey!
# 392                                          Calm Down
# 393                                  Jhoome Jo Pathaan
# 394                                Escapism. - Sped Up
# 395                                         Space Song
# 396  Dreamers [Music from the FIFA World Cup Qatar ...
# 397                                        Te Felicito
# 398                                           Muï¿½ï¿½
# 399                                                 TV
# 400                               I'm Not The Only One
# 401                                            Heather
# 402                     Besharam Rang (From "Pathaan")
# 403                           One Kiss (with Dua Lipa)
# 404                                    Sugar Rush Ride
# 405                                         Pink Venom
# 406                    WAIT FOR U (feat. Drake & Tems)
# 407                                    Don't Start Now
# 408                                         After Dark
# 409                           Eu Gosto Assim - Ao Vivo
# 410                  INDUSTRY BABY (feat. Jack Harlow)
# 411                                MIDDLE OF THE NIGHT
# 412                                           Atlantis
# 413                                           PUNTO 40
# 414                                       Evoque Prata
# 415                               How Do I Say Goodbye
# 416                                              Blind
# 417                                        Die For You
# 418                                               Doja
# 419                                             Gatita
# 420                                             Rumble
# 421  Niagara Falls (Foot or 2) [with Travis Scott &...
# 422                                           Yonaguni
# 423                                  Super Freaky Girl
# 424             Running Up That Hill (A Deal With God)
# 425                                           Dream On
# 426                                              Limbo
# 427                                  Where Are You Now
# 428                                      WORTH NOTHING
# 429                                         Bad Habits
# 430                                          KICK BACK
# 431         Evergreen (You Didnï¿½ï¿½ï¿½t Deserve Me A
# 432                                          Good Days
# 433                          Levitating (feat. DaBaby)
# 434                                              Woman
# 435                Shut up My Moms Calling - (Sped Up)
# 436                                            Ferrari
# 437                            You're On Your Own, Kid
# 438                       Kesariya (From "Brahmastra")
# 439                                    Agudo Mï¿½ï¿½gi
# 440                                           Payphone
# 441                    All I Want for Christmas Is You
# 442                                     Last Christmas
# 443                  Rockin' Around The Christmas Tree
# 444                                   Jingle Bell Rock
# 445        It's Beginning To Look A Lot Like Christmas
# 446                                      Santa Tell Me
# 447           It's the Most Wonderful Time of the Year
# 448             Let It Snow! Let It Snow! Let It Snow!
# 449                                            Snowman
# 450                                Underneath the Tree
# 451                                      Feliz Navidad
# 452                              Holly Jolly Christmas
# 453                                          Mistletoe
# 454                                        Sleigh Ride
# 455                                     Seek & Destroy
# 456                                      Love Language
# 457                           Happy Xmas (War Is Over)
# 458                           Used (feat. Don Toliver)
# 459           A Holly Jolly Christmas - Single Version
# 460  The Christmas Song (Merry Christmas To You) - ...
# 461  Wonderful Christmastime - Edited Version / Rem...
# 462        Do They Know It's Christmas? - 1984 Version
# 463       Ghost in the Machine (feat. Phoebe Bridgers)
# 464                                            Special
# 465                           Merry Christmas Everyone
# 466             Let It Snow! Let It Snow! Let It Snow!
# 467                                                SOS
# 468                     Open Arms (feat. Travis Scott)
# 469                                    White Christmas
# 470         Driving Home for Christmas - 2019 Remaster
# 471                  Christmas (Baby Please Come Home)
# 472                                          Gone Girl
# 473                                                F2F
# 474                                          Notice Me
# 475                                    Merry Christmas
# 476  It's Beginning to Look a Lot Like Christmas (w...
# 477                           My Only Wish (This Year)
# 478                                       Antidepresan
# 479                         Wild Flower (with youjeen)
# 480                                           I Hate U
# 481             Raindrops (Insane) [with Travis Scott]
# 482                                   SPIT IN MY FACE!
# 483                    Deck The Hall - Remastered 1999
# 484                              Smoking on my Ex Pack
# 485                                          Conceited
# 486             Snow On The Beach (feat. Lana Del Rey)
# 487                                             Maroon
# 488                                    Tubarï¿½ï¿½o Te
# 489                                          Bejeweled
# 490                                              Tarot
# 491  You Make It Feel Like Christmas (feat. Blake S...
# 492                                       Desesperados
# 493                                           Too Late
# 494                                              Party
# 495                   Run Rudolph Run - Single Version
# 496                     Jingle Bells - Remastered 1999
# 497                                                Far
# 498                         On Time (with John Legend)
# 499                                          GATï¿½ï¿½
# 500                                         ýýýabcdefu
# 501                                          Sacrifice
# 502                             Is There Someone Else?
# 503                                    Fingers Crossed
# 504                                        Out of Time
# 505                                        Do It To It
# 506                          We Don't Talk About Bruno
# 507                                              Pepas
# 508                         How Do I Make You Love Me?
# 509                                           Gasoline
# 510                                           Infinity
# 511                                     Less Than Zero
# 512                                     Take My Breath
# 513                                           good 4 u
# 514     Here We Goï¿½ï¿½ï¿½ Again (feat. Tyler, the Cr
# 515                                       Best Friends
# 516                           Kiss Me More (feat. SZA)
# 517           I Heard You're Married (feat. Lil Wayne)
# 518                                       Need To Know
# 519                     MONTERO (Call Me By Your Name)
# 520                           love nwantiti (ah ah ah)
# 521                                            Dawn FM
# 522                                   Surface Pressure
# 523                                        Starry Eyes
# 524                                  THATS WHAT I WANT
# 525                    One Right Now (with The Weeknd)
# 526                                             Beggin
# 527                                  Mon Amour - Remix
# 528  Lo Siento BB:/ (with Bad Bunny & Julieta Venegas)
# 529                                              MONEY
# 530                                          The Motto
# 531                                  Happier Than Ever
# 532                  Moth To A Flame (with The Weeknd)
# 533                                            traitor
# 534                                              Toxic
# 535                                    drivers license
# 536                                        Malvadï¿½ï¿
# 537  All Too Well (10 Minute Version) (Taylor's Ver...
# 538                             Donï¿½ï¿½ï¿½t Break My
# 539                                          Oh My God
# 540          Entre Nosotros (Remix) [con Nicki Nicole]
# 541                                   A Tale By Quincy
# 542                                         I AM WOMAN
# 543                                            Medallo
# 544                                      It'll Be Okay
# 545                                           Softcore
# 546                                      Super Gremlin
# 547                                             Volvï¿
# 548                                         Todo De Ti
# 549                              Love Nwantiti - Remix
# 550                              Smokin Out The Window
# 551                                Meet Me At Our Spot
# 552                          Every Angel is Terrifying
# 553                                      Tacones Rojos
# 554             Peaches (feat. Daniel Caesar & Giveon)
# 555                                             Dakiti
# 556            Tiago PZK: Bzrp Music Sessions, Vol. 48
# 557                                          Lï¿½ï¿½ï¿
# 558                                        Nostï¿½ï¿½l
# 559         Better Days (NEIKED x Mae Muller x Polo G)
# 560                                       Life Goes On
# 561       Sad Girlz Luv Money Remix (feat. Kali Uchis)
# 562                                             Butter
# 563                        pushin P (feat. Young Thug)
# 564                                          You Right
# 565                                            deja vu
# 566                                           Dynamite
# 567                                        TO THE MOON
# 568                                   Lost in the Fire
# 569                                    Salimo de Noche
# 570                                    Volando - Remix
# 571                                Leave The Door Open
# 572        Knife Talk (with 21 Savage ft. Project Pat)
# 573                                       Don't Be Shy
# 574                Love Grows (Where My Rosemary Goes)
# 575                          LA FAMA (with The Weeknd)
# 576                                The Family Madrigal
# 577                              Phantom Regret by Jim
# 578                                      Dos Oruguitas
# 579                                             Freaks
# 580                                           Acapulco
# 581                                       Daddy Issues
# 582                              thought i was playing
# 583                                             ELEVEN
# 584                             Mood (feat. Iann Dior)
# 585                                What Else Can I Do?
# 586                                         DANCE CRIP
# 587                                      Miserable Man
# 588                                            happier
# 589                                         Praise God
# 590                                  Get Into It (Yuh)
# 591                                      Before You Go
# 592                                                Sky
# 593                                Rolling in the Deep
# 594                                             Sobrio
# 595                                               Peru
# 596                                     favorite crime
# 597                                            Thunder
# 598                                       The Business
# 599                                          positions
# 600                              I WANNA BE YOUR SLAVE
# 601                               Vai Lï¿½ï¿½ Em Casa
# 602                                          The Feels
# 603                             HEARTBREAK ANNIVERSARY
# 604                                             No Lie
# 605              OUT OUT (feat. Charli XCX & Saweetie)
# 606                                 Pope Is a Rockstar
# 607                                               2055
# 608                                              Bored
# 609                           Happier Than Ever - Edit
# 610                             Astronaut In The Ocean
# 611                                           Ley Seca
# 612                                   Every Summertime
# 613                                Talking To The Moon
# 614                                 you broke me first
# 615                                         The Nights
# 616                                     Take My Breath
# 617              Way 2 Sexy (with Future & Young Thug)
# 618                                            Cï¿½ï¿½
# 619   Enemy - from the series Arcane League of Legends
# 620                                       Dance Monkey
# 621                                       Lucid Dreams
# 622                                    Quï¿½ï¿½ Mï¿½ï¿
# 623                                          All of Me
# 624          Smells Like Teen Spirit - Remastered 2021
# 625                                             Arcade
# 626                     Fair Trade (with Travis Scott)
# 627                                                Bar
# 628                             The Rumbling (TV Size)
# 629                  family ties (with Kendrick Lamar)
# 630                                     Mr. Brightside
# 631                                     Blessed-Cursed
# 632                                           AM Remix
# 633                                            Streets
# 634                                            Shallow
# 635                                      Polaroid Love
# 636     Leave Before You Love Me (with Jonas Brothers)
# 637                                Permission to Dance
# 638  Friday (feat. Mufasa & Hypeman) - Dopamine Re-...
# 639                                            RAPSTAR
# 640                                   'Till I Collapse
# 641                                           Memories
# 642                                           Se Le Ve
# 643                        25k jacket (feat. Lil Baby)
# 644                  When Iï¿½ï¿½ï¿½m Gone (with Katy
# 645                           Esqueï¿½ï¿½a-Me Se For C
# 646                                          Miï¿½ï¿½n
# 647                                            Sï¿½ï¿½
# 648                                             MAMIII
# 649                                       Still D.R.E.
# 650                     Stay Alive (Prod. SUGA of BTS)
# 651                                          Boyfriend
# 652       The Joker And The Queen (feat. Taylor Swift)
# 653                                   The Next Episode
# 654                                       Light Switch
# 655                                       City of Gods
# 656                                            Brividi
# 657                                               Lost
# 658                                         In Da Club
# 659                               she's all i wanna be
# 660                                 Ginseng Strip 2002
# 661  All For Us - from the HBO Original Series Euph...
# 662                                             Notion
# 663                                            Formula
# 664                                      Mount Everest
# 665                                            Excuses
# 666                                         Cigarettes
# 667  Cayï¿½ï¿½ La Noche (feat. Cruz Cafunï¿½ï¿½, Ab...
# 668      California Love - Original Version (Explicit)
# 669                                   Forgot About Dre
# 670                       Down Under (feat. Colin Hay)
# 671                                          Mujeriego
# 672                                            HUMBLE.
# 673                                               Stan
# 674                                         Contection
# 675                                               Swim
# 676                                        A Tu Merced
# 677                                    Numb Little Bug
# 678                                                212
# 679                                         Problemï¿½
# 680                                             Bussin
# 681                                          Worst Day
# 682                                            Malvada
# 683                                        Hrs and Hrs
# 684                                        Alien Blues
# 685                                  Thinking Out Loud
# 686                           Still Don't Know My Name
# 687                                     Christmas Tree
# 688                                Mal Feito - Ao Vivo
# 689                                      When I R.I.P.
# 690                              Do We Have A Problem?
# 691                                            Forever
# 692                               Gospel (with Eminem)
# 693                                          Seï¿½ï¿½o
# 694                                     NEW MAGIC WAND
# 695                                          Adore You
# 696                                           La Santa
# 697             Something In The Way - Remastered 2021
# 698                                       Sweetest Pie
# 699                         Bam Bam (feat. Ed Sheeran)
# 700                             Una Noche en Medellï¿½
# 701                                           Envolver
# 702                                          Starlight
# 703                                 Hati-Hati di Jalan
# 704  I'm Tired - From "Euphoria" An Original HBO Se...
# 705                                         DANï¿½ï¿½A
# 706                        Yo Voy (feat. Daddy Yankee)
# 707            Residente: Bzrp Music Sessions, Vol. 49
# 708                                             Jordan
# 709                                          Nail Tech
# 710                                              Chale
# 711                                             DARARI
# 712                             Ya No Somos Ni Seremos
# 713                              Thinking with My Dick
# 714                                       Freaky Deaky
# 715            this is what falling in love feels like
# 716                                            La Zona
# 717                Bohemian Rhapsody - Remastered 2011
# 718                                               Hope
# 719                                         Levitating
# 720                            Wake Me Up - Radio Edit
# 721                                 jealousy, jealousy
# 722                                      Monï¿½ï¿½y so
# 723                                 Demasiadas Mujeres
# 724                           Something Just Like This
# 725                                             Closer
# 726                                                O.O
# 727                       Somebody That I Used To Know
# 728                                        Tom's Diner
# 729                                        First Class
# 730                                             Plan A
# 731                                  Fuera del mercado
# 732                                      X ï¿½ï¿½LTIMA
# 733                                   When You're Gone
# 734                                         In My Head
# 735                                     Wait a Minute!
# 736                                          LOVE DIVE
# 737                                          Pantysito
# 738                                             Chance
# 739                                Cool for the Summer
# 740                         psychofreak (feat. WILLOW)
# 741                                         Angel Baby
# 742                                            Vampiro
# 743                                Si Quieren Frontear
# 744                                           Right On
# 745                                      Me Arrepentï¿
# 746                                   That's Hilarious
# 747                                       Soy El Unico
# 748                                          RUMBATï¿½
# 749                               sentaDONA (Remix) s2
# 750                                            Falling
# 751                                              Sigue
# 752                               Fim de Semana no Rio
# 753                                             MANIAC
# 754                    There's Nothing Holdin' Me Back
# 755                             IDGAF (with blackbear)
# 756                                             Golden
# 757                             Get Lucky - Radio Edit
# 758                                         Ain't Shit
# 759                 Nobody Like U - From "Turning Red"
# 760                                         Still Life
# 761                                         Photograph
# 762                                      Love Yourself
# 763                                                N95
# 764                                    About Damn Time
# 765                                           Die Hard
# 766                               Despuï¿½ï¿½s de la P
# 767                                          Un Ratito
# 768                                    United In Grief
# 769                         Father Time (feat. Sampha)
# 770                                   Yo No Soy Celoso
# 771                                        Rich Spirit
# 772                       Cooped Up (with Roddy Ricch)
# 773                               Me Fui de Vacaciones
# 774                                        Silent Hill
# 775                                       La Corriente
# 776                                       Count Me Out
# 777                                             Andrea
# 778                                         Dos Mil 16
# 779                                    We Cry Together
# 780                                             Savior
# 781                                            Un Coco
# 782                                     Otro Atardecer
# 783                                 Worldwide Steppers
# 784                                           Aguacero
# 785                                      Purple Hearts
# 786                                   Un Verano Sin Ti
# 787                                         ULTRA SOLO
# 788                                Ensï¿½ï¿½ï¿½ï¿½ame
# 789                                         El Apagï¿½
# 790                                           Callaita
# 791                                           Dua Lipa
# 792                                             Agosto
# 793                                  House Of Memories
# 794                                         Mr. Morale
# 795              That That (prod. & feat. SUGA of BTS)
# 796                                       In The Stars
# 797                                   Rich - Interlude
# 798                                         SUPERMODEL
# 799                        Stefania (Kalush Orchestra)
# 800                                     Thousand Miles
# 801                                              Crown
# 802                                     Auntie Diaries
# 803                                  PUFFIN ON ZOOTIEZ
# 804                                             Mirror
# 805                                     Beautiful Girl
# 806         Paulo Londra: Bzrp Music Sessions, Vol. 23
# 807                                 Savior - Interlude
# 808                                            Pasoori
# 809  Mother I Sober (feat. Beth Gibbons of Portishead)
# 810                                      TUS Lï¿½ï¿½GR
# 811                                  Where Did You Go?
# 812                              I Tried to Tell Y'all
# 813                         Honest (feat. Don Toliver)
# 814                                               ZOOM
# 815                                              SloMo
# 816                                           FEARLESS
# 817                         10 Things I Hate About You
# 818                                          SPACE MAN
# 819                                           With you
# 820                                               Iris
# 821                                   The Heart Part 5
# 822                                          San Lucas
# 823                     This Love (Taylorï¿½ï¿½ï¿½s Ve
# 824                                       Good Looking
# 825                                            Flowers
# ...
# 191              3
# 192             25
# 193              8
# 194             10
# 195              3
# 196              4
# 197              7
# 198             11
# 199              5
# 200              6
# 201             28
# 202             12
# 203             10
# 204              4
# 205             33
# 206              4
# 207              4
# 208              5
# 209             49
# 210              3
# 211              9
# 212             13
# 213              4
# 214             15
# 215              6
# 216             11
# 217             19
# 218              6
# 219             21
# 220              4
# 221              6
# 222             13
# 223              3
# 224             16
# 225             14
# 226              3
# 227             12
# 228             13
# 229              5
# 230              4
# 231             14
# 232              8
# 233             23
# 234             15
# 235              7
# 236              4
# 237              8
# 238              8
# 239              5
# 240              9
# 241             22
# 242              3
# 243              8
# 244              4
# 245             24
# 246              3
# 247             64
# 248             12
# 249              5
# 250              6
# 251             11
# 252              5
# 253              5
# 254              5
# 255              5
# 256              5
# 257             30
# 258              5
# 259             39
# 260              5
# 261             25
# 262              3
# 263              3
# 264              5
# 265              4
# 266             36
# 267              9
# 268             42
# 269              3
# 270              4
# 271              5
# 272             19
# 273              5
# 274              9
# 275              9
# 276              6
# 277              3
# 278             10
# 279              7
# 280              4
# 281              3
# 282             15
# 283              4
# 284             10
# 285              4
# 286              5
# 287              6
# 288              3
# 289              5
# 290              4
# 291             16
# 292              4
# 293              4
# 294              4
# 295              4
# 296             26
# 297              6
# 298              8
# 299              6
# 300             20
# 301             30
# 302             32
# 303             10
# 304             20
# 305              4
# 306             35
# 307              7
# 308              5
# 309              3
# 310              3
# 311              3
# 312              4
# 313              7
# 314              7
# 315              4
# 316              3
# 317              6
# 318              3
# 319             11
# 320              6
# 321             31
# 322              4
# 323              6
# 324              5
# 325              8
# 326             10
# 327              5
# 328              5
# 329              5
# 330              6
# 331              4
# 332              6
# 333             13
# 334              3
# 335              5
# 336              3
# 337              3
# 338              6
# 339              3
# 340              3
# 341             38
# 342              4
# 343              4
# 344              3
# 345              6
# 346              5
# 347              3
# 348             26
# 349              4
# 350              3
# 351             29
# 352             23
# 353              3
# 354              5
# 355              3
# 356              7
# 357              3
# 358              6
# 359              3
# 360              4
# 361              7
# 362              5
# 363             13
# 364             33
# 365             28
# 366             26
# 367              5
# 368             32
# 369              2
# 370              3
# 371              3
# 372              7
# 373              4
# 374              5
# 375              6
# 376              4
# 377              3
# 378              4
# 379              3
# 380             27
# 381              6
# 382              9
# 383              8
# 384              4
# 385              4
# 386             10
# 387              3
# 388              5
# 389              4
# 390             10
# 391              6
# 392              4
# 393              7
# 394             20
# 395              3
# 396              4
# 397             32
# 398              8
# 399              4
# 400              4
# 401              3
# 402              4
# 403             11
# 404              9
# 405             10
# 406             34
# 407              8
# 408              3
# 409              4
# 410              6
# 411              5
# 412              3
# 413              9
# 414             24
# 415              7
# 416              4
# 417              5
# 418             29
# 419              6
# 420              6
# 421             29
# 422             12
# 423             24
# 424              6
# 425              3
# 426             46
# 427             10
# 428              8
# 429              3
# 430             11
# 431              4
# 432              6
# 433              6
# 434              9
# 435             10
# 436              5
# 437              6
# 438              3
# 439              5
# 440              4
# 441              4
# 442              3
# 443              5
# 444              3
# 445              3
# 446             18
# 447              4
# 448              4
# 449              3
# 450              5
# 451              4
# 452              4
# 453              4
# 454              3
# 455              7
# 456              8
# 457              3
# 458              9
# 459              3
# 460              4
# 461              3
# 462              3
# 463              5
# 464              5
# 465              3
# 466              6
# 467             23
# 468             16
# 469              3
# 470              4
# 471              5
# 472              6
# 473              4
# 474             12
# 475              4
# 476              5
# 477              3
# 478              3
# 479              9
# 480             16
# 481              5
# 482              7
# 483              4
# 484             38
# 485              7
# 486              4
# 487              6
# 488             36
# 489              7
# 490              4
# 491              4
# 492              8
# 493              8
# 494              9
# 495              8
# 496              5
# 497              8
# 498              6
# 499             39
# 500              5
# 501             10
# 502              3
# 503              5
# 504              5
# 505              9
# 506              8
# 507              3
# 508              8
# 509              5
# 510              4
# 511              3
# 512              4
# 513             18
# 514              3
# 515             21
# 516              3
# 517             19
# 518              7
# 519             15
# 520              4
# 521              5
# 522             31
# 523              3
# 524             22
# 525              5
# 526              5
# 527             10
# 528              8
# 529             23
# 530              4
# 531              4
# 532              4
# 533              5
# 534             36
# 535              7
# 536             27
# 537              3
# 538              3
# 539              5
# 540              4
# 541             11
# 542             16
# 543              8
# 544              3
# 545              3
# 546             14
# 547             18
# 548              4
# 549              6
# 550              4
# 551              3
# 552             29
# 553              3
# 554             18
# 555              5
# 556             32
# 557             11
# 558              5
# 559              4
# 560              8
# 561              6
# 562             11
# 563             19
# 564              6
# 565              9
# 566             10
# 567             35
# 568              4
# 569              5
# 570              7
# 571              3
# 572             30
# 573              6
# 574              3
# 575              5
# 576             36
# 577              4
# 578              5
# 579              5
# 580              5
# 581              3
# 582              7
# 583             11
# 584              4
# 585              4
# 586              9
# 587              3
# 588             13
# 589             17
# 590             16
# 591              6
# 592             21
# 593              3
# 594             22
# 595              9
# 596              4
# 597              6
# 598             23
# 599             12
# 600              4
# 601             28
# 602              7
# 603              5
# 604             13
# 605              5
# 606              3
# 607             31
# 608              5
# 609              3
# 610              9
# 611             10
# 612              4
# 613              3
# 614              5
# 615              4
# 616              5
# 617             14
# 618              5
# 619             23
# 620             10
# 621             24
# 622             11
# 623              3
# 624              7
# 625              4
# 626             26
# 627              8
# 628              5
# 629             33
# 630              8
# 631              6
# 632             16
# 633              8
# 634              3
# 635              4
# 636              4
# 637              4
# 638             13
# 639             24
# 640             20
# 641              5
# 642             11
# 643             28
# 644              3
# 645              7
# 646              7
# 647              8
# 648              8
# 649             24
# 650              7
# 651              6
# 652              3
# 653             25
# 654             31
# 655             38
# 656              3
# 657             22
# 658             37
# 659              4
# 660              4
# 661              9
# 662              8
# 663              4
# 664             22
# 665              8
# 666              4
# 667             30
# 668              4
# 669              8
# 670             17
# 671             13
# 672             12
# 673             21
# 674             34
# 675              4
# 676              6
# 677              9
# 678              7
# 679              6
# 680              5
# 681             40
# 682              5
# 683             18
# 684              3
# 685              3
# 686             12
# 687              4
# 688              7
# 689             21
# 690             40
# 691              3
# 692             24
# 693              3
# 694             11
# 695              5
# 696              5
# 697              3
# 698             22
# 699              4
# 700              8
# 701              8
# 702             28
# 703              4
# 704              3
# 705              8
# 706             24
# 707             40
# 708             37
# 709              9
# 710              4
# 711              4
# 712              3
# 713             20
# 714              4
# 715              6
# 716              4
# 717              5
# 718              6
# 719              8
# 720              5
# 721             13
# 722              9
# 723             39
# 724              4
# 725              3
# 726             29
# 727              4
# 728             14
# 729             10
# 730              4
# 731             14
# 732              5
# 733              4
# 734             12
# 735              3
# 736              4
# 737              6
# 738              6
# 739              4
# 740              8
# 741              3
# 742              4
# 743             23
# 744             34
# 745             16
# 746              6
# 747              3
# 748              4
# 749             27
# 750              3
# 751              7
# 752             10
# 753             41
# 754              6
# 755              8
# 756              6
# 757              4
# 758             21
# 759             15
# 760              3
# 761              5
# 762             44
# 763             14
# 764              7
# 765             27
# 766             31
# 767              5
# 768             43
# 769             35
# 770              5
# 771             21
# 772             33
# 773              5
# 774              9
# 775             20
# 776              9
# 777             38
# 778              5
# 779             36
# 780             46
# 781              6
# 782              4
# 783             36
# 784              7
# 785             29
# 786              6
# 787             21
# 788              8
# 789             31
# 790             31
# 791              8
# 792             12
# 793              3
# 794             32
# 795              9
# 796              5
# 797              9
# 798              6
# 799              4
# 800              8
# 801              4
# 802             38
# 803             31
# 804              7
# 805              9
# 806              9
# 807             19
# 808              4
# 809             35
# 810             25
# 811              4
# 812             36
# 813              6
# 814             16
# 815              6
# 816             14
# 817              5
# 818              5
# 819              3
# 820              4
# 821             34
# 822              3
# 823              4
# 824              3
# 825             39
# 826             19
# 827             17
# 828              4
# 829              4
# 830              4
# 831              4
# 832             26
# 833              6
# 834              5
# 835             11
# 836              4
# 837             14
# 838             25
# 839              3
# 840              5
# 841              6
# 842              5
# 843              3
# 844              4
# 845             14
# 846             23
# 847              4
# 848             34
# 849              8
# 850              3
# 851              3
# 852              5
# 853              5
# 854              3
# 855              4
# 856              3
# 857             11
# 858              4
# 859             20
# 860              3
# 861              4
# 862              4
# 863              8
# 864              8
# 865              6
# 866              8
# 867              4
# 868              5
# 869              7
# 870              4
# 871              5
# 872              9
# 873              7
# 874             14
# 875             23
# 876             25
# 877             11
# 878             13
# 879             11
# 880             45
# 881             23
# 882             12
# 883              8
# 884             45
# 885              8
# 886             40
# 887             10
# 888              4
# 889              4
# 890              6
# 891              4
# 892             14
# 893             14
# 894              4
# 895              4
# 896             12
# 897              3
# 898              8
# 899             11
# 900              4
# 901             12
# 902              5
# 903              5
# 904             12
# 905             26
# 906              7
# 907              7
# 908             25
# 909              7
# 910              2
# 911              3
# 912             23
# 913              7
# 914              4
# 915              4
# 916              6
# 917              5
# 918              3
# 919              4
# 920              8
# 921             18
# 922              5
# 923              3
# 924             11
# 925              4
# 926             10
# 927              4
# 928             46
# 929             36
# 930             44
# 931             32
# 932             12
# 933             39
# 934             17
# 935             59
# 936             14
# 937              7
# 938              4
# 939              5
# 940              5
# 941             12
# 942              3
# 943             20
# 944              3
# 945             32
# 946             27
# 947              4
# 948              3
# 949              6
# 950              6
# 951              5
# 952              5

# %% [markdown]
# # Overview of DataSet
#
# #### • How many rows and columns does the datase contain?
# #### • What are the data types of each column? Are there any missing values?

# %%
rows, columns = df.shape
print(f"The DataFrame has {rows} rows and {columns} columns.")
# Out:
# The DataFrame has 953 rows and 24 columns.

# %%
data_types = pd.DataFrame(df.dtypes, columns=['Data Type']).reset_index()
data_types.columns = ['Column', 'Data Type']

missing_values = pd.DataFrame(df.isnull().sum(), columns=['Missing Values']).reset_index()
missing_values.columns = ['Column', 'Missing Values']

# Merging data types and missing values
overview_table = pd.merge(data_types, missing_values, on='Column')
display(overview_table.style.set_caption("Dataset Overview"))
# Out:
# <style type="text/css">
# </style>
# <table id="T_25835">
#   <caption>Dataset Overview</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_25835_level0_col0" class="col_heading level0 col0" >Column</th>
#       <th id="T_25835_level0_col1" class="col_heading level0 col1" >Data Type</th>
#       <th id="T_25835_level0_col2" class="col_heading level0 col2" >Missing Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_25835_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_25835_row0_col0" class="data row0 col0" >track_name</td>
#       <td id="T_25835_row0_col1" class="data row0 col1" >object</td>
#       <td id="T_25835_row0_col2" class="data row0 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_25835_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_25835_row1_col0" class="data row1 col0" >artist(s)_name</td>
#       <td id="T_25835_row1_col1" class="data row1 col1" >object</td>
#       <td id="T_25835_row1_col2" class="data row1 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_25835_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_25835_row2_col0" class="data row2 col0" >artist_count</td>
#       <td id="T_25835_row2_col1" class="data row2 col1" >int64</td>
#       <td id="T_25835_row2_col2" class="data row2 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_25835_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_25835_row3_col0" class="data row3 col0" >released_year</td>
#       <td id="T_25835_row3_col1" class="data row3 col1" >int64</td>
#       <td id="T_25835_row3_col2" class="data row3 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_25835_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_25835_row4_col0" class="data row4 col0" >released_month</td>
#       <td id="T_25835_row4_col1" class="data row4 col1" >int64</td>
#       <td id="T_25835_row4_col2" class="data row4 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_25835_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_25835_row5_col0" class="data row5 col0" >released_day</td>
#       <td id="T_25835_row5_col1" class="data row5 col1" >int64</td>
#       <td id="T_25835_row5_col2" class="data row5 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_25835_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_25835_row6_col0" class="data row6 col0" >in_spotify_playlists</td>
#       <td id="T_25835_row6_col1" class="data row6 col1" >int64</td>
#       <td id="T_25835_row6_col2" class="data row6 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_25835_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_25835_row7_col0" class="data row7 col0" >in_spotify_charts</td>
#       <td id="T_25835_row7_col1" class="data row7 col1" >int64</td>
#       <td id="T_25835_row7_col2" class="data row7 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_25835_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_25835_row8_col0" class="data row8 col0" >streams</td>
#       <td id="T_25835_row8_col1" class="data row8 col1" >object</td>
#       <td id="T_25835_row8_col2" class="data row8 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_25835_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_25835_row9_col0" class="data row9 col0" >in_apple_playlists</td>
#       <td id="T_25835_row9_col1" class="data row9 col1" >int64</td>
#       <td id="T_25835_row9_col2" class="data row9 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_25835_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_25835_row10_col0" class="data row10 col0" >in_apple_charts</td>
#       <td id="T_25835_row10_col1" class="data row10 col1" >int64</td>
#       <td id="T_25835_row10_col2" class="data row10 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_25835_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_25835_row11_col0" class="data row11 col0" >in_deezer_playlists</td>
#       <td id="T_25835_row11_col1" class="data row11 col1" >object</td>
#       <td id="T_25835_row11_col2" class="data row11 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_25835_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_25835_row12_col0" class="data row12 col0" >in_deezer_charts</td>
#       <td id="T_25835_row12_col1" class="data row12 col1" >int64</td>
#       <td id="T_25835_row12_col2" class="data row12 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_25835_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_25835_row13_col0" class="data row13 col0" >in_shazam_charts</td>
#       <td id="T_25835_row13_col1" class="data row13 col1" >object</td>
#       <td id="T_25835_row13_col2" class="data row13 col2" >50</td>
#     </tr>
#     <tr>
#       <th id="T_25835_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_25835_row14_col0" class="data row14 col0" >bpm</td>
#       <td id="T_25835_row14_col1" class="data row14 col1" >int64</td>
#       <td id="T_25835_row14_col2" class="data row14 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_25835_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_25835_row15_col0" class="data row15 col0" >key</td>
#       <td id="T_25835_row15_col1" class="data row15 col1" >object</td>
#       <td id="T_25835_row15_col2" class="data row15 col2" >95</td>
#     </tr>
#     <tr>
#       <th id="T_25835_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_25835_row16_col0" class="data row16 col0" >mode</td>
#       <td id="T_25835_row16_col1" class="data row16 col1" >object</td>
#       <td id="T_25835_row16_col2" class="data row16 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_25835_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_25835_row17_col0" class="data row17 col0" >danceability_%</td>
#       <td id="T_25835_row17_col1" class="data row17 col1" >int64</td>
#       <td id="T_25835_row17_col2" class="data row17 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_25835_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_25835_row18_col0" class="data row18 col0" >valence_%</td>
#       <td id="T_25835_row18_col1" class="data row18 col1" >int64</td>
#       <td id="T_25835_row18_col2" class="data row18 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_25835_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_25835_row19_col0" class="data row19 col0" >energy_%</td>
#       <td id="T_25835_row19_col1" class="data row19 col1" >int64</td>
#       <td id="T_25835_row19_col2" class="data row19 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_25835_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_25835_row20_col0" class="data row20 col0" >acousticness_%</td>
#       <td id="T_25835_row20_col1" class="data row20 col1" >int64</td>
#       <td id="T_25835_row20_col2" class="data row20 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_25835_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_25835_row21_col0" class="data row21 col0" >instrumentalness_%</td>
#       <td id="T_25835_row21_col1" class="data row21 col1" >int64</td>
#       <td id="T_25835_row21_col2" class="data row21 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_25835_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_25835_row22_col0" class="data row22 col0" >liveness_%</td>
#       <td id="T_25835_row22_col1" class="data row22 col1" >int64</td>
#       <td id="T_25835_row22_col2" class="data row22 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_25835_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_25835_row23_col0" class="data row23 col0" >speechiness_%</td>
#       <td id="T_25835_row23_col1" class="data row23 col1" >int64</td>
#       <td id="T_25835_row23_col2" class="data row23 col2" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # BASIC DESCRIPTIVE STATISTICS
#
# #### • What are the mean, median, and standard deviation of the streams column?
# #### • What is the distribution of released_year and artist_count? Are there any noticeable trends or outliers?

# %%
import pandas as pd

# Statistics for Streams

# Display streams statistics as DataFrame
streams = pd.to_numeric(df['streams'], errors='coerce')  # Convert to numeric, replacing errors with NaN
streams_stats_df = pd.DataFrame({
    "Statistic": ["Mean", "Median", "Standard Deviation"],
    "Streams": [streams.mean(), streams.median(), streams.std()]
})

# Display streams statistics as DataFrame with formatted numbers
print("Statistics for Streams:")
display(streams_stats_df.style.format({"Streams": "{:,.2f}"}))
print("\n")

# Distribution of released_year
year_dist_df = df['released_year'].value_counts().sort_index().reset_index()
year_dist_df.columns = ["Released Year", "Count"]

# Summary Statistics for Released Year
released_year_summary_df = df['released_year'].describe().to_frame(name="Released Year Stats").reset_index()
released_year_summary_df.columns = ["Statistic", "Value"]

# Display year distribution and summary statistics as DataFrames
print("Distribution of Released Year:")
display(year_dist_df)
print("\nSummary Statistics for Released Year:")
display(released_year_summary_df)
print("\n")

# Distribution of artist_count
artist_count_dist_df = df['artist_count'].value_counts().sort_index().reset_index()
artist_count_dist_df.columns = ["Artist Count", "Count"]

# Summary Statistics for Artist Count
artist_count_summary_df = df['artist_count'].describe().to_frame(name="Artist Count Stats").reset_index()
artist_count_summary_df.columns = ["Statistic", "Value"]

# Display artist count distribution and summary statistics as DataFrames
print("Distribution of Artist Count:")
display(artist_count_dist_df)
print("\nSummary Statistics for Artist Count:")
display(artist_count_summary_df)
# Out:
# Statistics for Streams:
# <style type="text/css">
# </style>
# <table id="T_881a0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_881a0_level0_col0" class="col_heading level0 col0" >Statistic</th>
#       <th id="T_881a0_level0_col1" class="col_heading level0 col1" >Streams</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_881a0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_881a0_row0_col0" class="data row0 col0" >Mean</td>
#       <td id="T_881a0_row0_col1" class="data row0 col1" >514,137,424.94</td>
#     </tr>
#     <tr>
#       <th id="T_881a0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_881a0_row1_col0" class="data row1 col0" >Median</td>
#       <td id="T_881a0_row1_col1" class="data row1 col1" >290,530,915.00</td>
#     </tr>
#     <tr>
#       <th id="T_881a0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_881a0_row2_col0" class="data row2 col0" >Standard Deviation</td>
#       <td id="T_881a0_row2_col1" class="data row2 col1" >566,856,949.04</td>
#     </tr>
#   </tbody>
# </table>
# Distribution of Released Year:
#     Released Year  Count
# 0            1930      1
# 1            1942      1
# 2            1946      1
# 3            1950      1
# 4            1952      1
# 5            1957      2
# 6            1958      3
# 7            1959      2
# 8            1963      3
# 9            1968      1
# 10           1970      2
# 11           1971      1
# 12           1973      1
# 13           1975      2
# 14           1979      1
# 15           1982      2
# 16           1983      1
# 17           1984      4
# 18           1985      2
# 19           1986      2
# 20           1987      1
# 21           1991      2
# 22           1992      1
# 23           1994      1
# 24           1995      2
# 25           1996      1
# 26           1997      1
# 27           1998      1
# 28           1999      5
# 29           2000      4
# 30           2002      6
# 31           2003      2
# 32           2004      4
# 33           2005      1
# 34           2007      1
# 35           2008      2
# 36           2010      7
# 37           2011     10
# 38           2012     10
# 39           2013     13
# 40           2014     13
# 41           2015     11
# 42           2016     18
# 43           2017     23
# 44           2018     10
# 45           2019     36
# 46           2020     37
# 47           2021    119
# 48           2022    402
# 49           2023    175
# Summary Statistics for Released Year:
#   Statistic        Value
# 0     count   953.000000
# 1      mean  2018.238195
# 2       std    11.116218
# 3       min  1930.000000
# 4       25%  2020.000000
# 5       50%  2022.000000
# 6       75%  2022.000000
# 7       max  2023.000000
# Distribution of Artist Count:
#    Artist Count  Count
# 0             1    587
# 1             2    254
# 2             3     85
# 3             4     15
# 4             5      5
# 5             6      3
# 6             7      2
# 7             8      2
# Summary Statistics for Artist Count:
#   Statistic       Value
# 0     count  953.000000
# 1      mean    1.556139
# 2       std    0.893044
# 3       min    1.000000
# 4       25%    1.000000
# 5       50%    1.000000
# 6       75%    2.000000
# 7       max    8.000000

# %% [markdown]
# # TOP PERFORMER
#
# #### • Which track has the highest number of streams? Display the top 5 most streamed tracks.
# #### • Who are the top 5 most frequent artists based on the number of tracks in the dataset?

# %%
# Sort the dataframe by streams in descending order and select the top 5 rows
top_5_streams = df.sort_values('streams', ascending=False).head(5)

# Select and display the desired columns in a formatted DataFrame
top_5_streams_df = top_5_streams[['track_name', 'artist(s)_name', 'streams']].reset_index(drop=True)

# Display the DataFrame
print("Top 5 Tracks by Streams:")
display(top_5_streams_df)
# Out:
# Top 5 Tracks by Streams:
#                             track_name     artist(s)_name  \
# 0  Love Grows (Where My Rosemary Goes)  Edison Lighthouse
# 1                            Anti-Hero       Taylor Swift
# 2                               Arcade    Duncan Laurence
# 3                        Glimpse of Us               Joji
# 4                       Seek & Destroy                SZA
#
#                                              streams
# 0  BPM110KeyAModeMajorDanceability53Valence75Ener...
# 1                                          999748277
# 2                                          991336132
# 3                                          988515741
# 4                                           98709329

# %%
# Get the top 5 artists by the number of tracks
top_5_artists = df['artist(s)_name'].value_counts().head(5).reset_index()
top_5_artists.columns = ["Artist(s) Name", "Number of Tracks"]

# Display the DataFrame
print("Top 5 Artists by Number of Tracks:")
display(top_5_artists)
# Out:
# Top 5 Artists by Number of Tracks:
#   Artist(s) Name  Number of Tracks
# 0   Taylor Swift                34
# 1     The Weeknd                22
# 2      Bad Bunny                19
# 3            SZA                19
# 4   Harry Styles                17

# %% [markdown]
# # TEMPORAL TRENDS
#
# #### • Analyze the trends in the number of tracks released over time. Plot the number of tracks released per year.
# #### • Does the number of tracks released per monthj follow any noticeable patterns? Which month sees the most releases?

# %%
tracks_per_year = df['released_year'].value_counts().sort_index()

# Plotting the number of tracks released per year
plt.figure(figsize=(12, 6))
tracks_per_year.plot(kind='bar', color='skyblue')
plt.title('Number of Tracks Released per Year')
plt.xlabel('Year')
plt.ylabel('Number of Tracks')
plt.xticks(rotation=45)
plt.grid(axis='y')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# #  Genre and Music Characteristics
# #### • Examine the correlation between streams and musical attributes like bpm, danceability_%, and energy_%. Which attributes seem to influence streams the most?
# #### •Is there a correlation between deanceability_% and energy_%? How aout valence_% and acousticness_%?

# %%
# Convert relevant columns to numeric, coercing errors to NaN
df['streams'] = pd.to_numeric(df['streams'], errors='coerce')
df['bpm'] = pd.to_numeric(df['bpm'], errors='coerce')
df['danceability_%'] = pd.to_numeric(df['danceability_%'], errors='coerce')
df['energy_%'] = pd.to_numeric(df['energy_%'], errors='coerce')
df['valence_%'] = pd.to_numeric(df['valence_%'], errors='coerce')
df['acousticness_%'] = pd.to_numeric(df['acousticness_%'], errors='coerce')
df['instrumentalness_%'] = pd.to_numeric(df['instrumentalness_%'], errors='coerce')
df['liveness_%'] = pd.to_numeric(df['liveness_%'], errors='coerce')
df['speechiness_%'] = pd.to_numeric(df['speechiness_%'], errors='coerce')

# Calculate correlation matrix and display it as a DataFrame
correlation_matrix = df[['streams', 'bpm', 'danceability_%', 'energy_%', 'valence_%', 
                         'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%']].corr()
correlation_matrix_df = correlation_matrix.reset_index().rename(columns={'index': 'Attribute'})

# Display correlation matrix as a DataFrame
print("Correlation Matrix:")
display(correlation_matrix_df)

# Plotting the correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap of Streams and Musical Attributes')
plt.show()

# Scatter plots for streams vs musical attributes
attributes = ['bpm', 'danceability_%', 'energy_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%']
for attr in attributes:
    plt.figure(figsize=(8, 5))
    sns.scatterplot(data=df, x=attr, y='streams')
    plt.title(f'Scatter Plot: Streams vs {attr}')
    plt.xlabel(attr)
    plt.ylabel('Streams')
    plt.grid()
    plt.show()

# Calculate and display specific correlations as DataFrames
danceability_energy_corr = df['danceability_%'].corr(df['energy_%'])
valence_acousticness_corr = df['valence_%'].corr(df['acousticness_%'])
liveness_speechiness_corr = df['liveness_%'].corr(df['speechiness_%'])

# Create a DataFrame to display these specific correlations
specific_correlations_df = pd.DataFrame({
    "Correlation Pair": ["Danceability vs Energy", "Valence vs Acousticness", "Liveness vs Speechiness"],
    "Correlation Value": [danceability_energy_corr, valence_acousticness_corr, liveness_speechiness_corr]
})

# Display the specific correlations
print("Specific Correlations:")
display(specific_correlations_df)
# Out:
# Correlation Matrix:
#             Attribute   streams       bpm  danceability_%  energy_%  \
# 0             streams  1.000000 -0.002438       -0.105457 -0.026051
# 1                 bpm -0.002438  1.000000       -0.147095  0.025794
# 2      danceability_% -0.105457 -0.147095        1.000000  0.198095
# 3            energy_% -0.026051  0.025794        0.198095  1.000000
# 4           valence_% -0.040831  0.041195        0.408451  0.357612
# 5      acousticness_% -0.004485 -0.017694       -0.236165 -0.577344
# 6  instrumentalness_% -0.044902 -0.001195       -0.089138 -0.038547
# 7          liveness_% -0.048337 -0.000761       -0.077538  0.117302
# 8       speechiness_% -0.112333  0.039260        0.184977 -0.004846
#
#    valence_%  acousticness_%  instrumentalness_%  liveness_%  speechiness_%
# 0  -0.040831       -0.004485           -0.044902   -0.048337      -0.112333
# 1   0.041195       -0.017694           -0.001195   -0.000761       0.039260
# 2   0.408451       -0.236165           -0.089138   -0.077538       0.184977
# 3   0.357612       -0.577344           -0.038547    0.117302      -0.004846
# 4   1.000000       -0.081907           -0.132890    0.021278       0.041081
# 5  -0.081907        1.000000            0.042796   -0.050142      -0.022501
# 6  -0.132890        0.042796            1.000000   -0.045967      -0.083396
# 7   0.021278       -0.050142           -0.045967    1.000000      -0.022525
# 8   0.041081       -0.022501           -0.083396   -0.022525       1.000000
# Specific Correlations:
#           Correlation Pair  Correlation Value
# 0   Danceability vs Energy           0.198095
# 1  Valence vs Acousticness          -0.081907
# 2  Liveness vs Speechiness          -0.022525

# %% [markdown]
# # PLATFORM POPULATIRY
#
# #### • How do the number of tracks in spotify_playlists, spotify_charts, and apple_playlists compare? Which platform seems to favor the most popular tracks?

# %%
# First, let's clean the data
columns_to_clean = ['streams', 'in_spotify_playlists', 'in_spotify_charts', 'in_apple_playlists']

for col in columns_to_clean:
    df[col] = pd.to_numeric(df[col].astype(str).str.replace(',', ''), errors='coerce')

# Calculate the total number of tracks for each platform
platform_counts = {
    'Spotify Playlists': df['in_spotify_playlists'].sum(),
    'Spotify Charts': df['in_spotify_charts'].sum(),
    'Apple Playlists': df['in_apple_playlists'].sum()
}

# Create a DataFrame for plotting
platform_df = pd.DataFrame(list(platform_counts.items()), columns=['Platform', 'Number of Tracks'])

# Plotting the number of tracks in each platform
plt.figure(figsize=(10, 6))
sns.barplot(data=platform_df, x='Platform', y='Number of Tracks', palette='viridis', hue='Platform')
plt.title('Number of Tracks in Different Platforms')
plt.ylabel('Number of Tracks')
plt.xlabel('Platform')
plt.xticks(rotation=15)
plt.grid(axis='y')

# Show the plot
plt.tight_layout()
plt.show()

# Analyze correlation of streams with playlist/chart presence
correlation_with_streams = df[columns_to_clean].corr()

# Display correlation results
print("Correlation with Streams:")
print(correlation_with_streams)

# Determine which platform favors the most popular tracks
most_popular_platform = correlation_with_streams['streams'].drop('streams').idxmax()
most_popular_value = correlation_with_streams['streams'].drop('streams').max()

print(f"The platform that seems to favor the most popular tracks is: {most_popular_platform} with a correlation of {most_popular_value:.2f}")
# Out:
# Correlation with Streams:
#                        streams  in_spotify_playlists  in_spotify_charts  \
# streams               1.000000              0.789822           0.245821
# in_spotify_playlists  0.789822              1.000000           0.164331
# in_spotify_charts     0.245821              0.164331           1.000000
# in_apple_playlists    0.772063              0.708277           0.233354
#
#                       in_apple_playlists
# streams                         0.772063
# in_spotify_playlists            0.708277
# in_spotify_charts               0.233354
# in_apple_playlists              1.000000
# The platform that seems to favor the most popular tracks is: in_spotify_playlists with a correlation of 0.79

# %% [markdown]
# # ADVANCE ANALYSIS
#
# #### • Based on the streams data, can you indentify any patterns among tracks with the same key or mode(Major vs Minor)?
# #### • Do certain genres or artists consistenly appear in more playlists or charts? Perfrom an analysus to compare the most frequently appearing artists in playlist or charts.

# %%
# 1. Analysis of Streams by Key and Mode
def analyze_key_mode_patterns(df):
    print("\n=== Analysis of Streams by Key and Mode ===")
    
    # Calculate average streams by key
    key_streams = df.groupby('key')['streams'].mean().sort_values(ascending=False)
    
    # Calculate average streams by mode
    mode_streams = df.groupby('mode')['streams'].mean()
    
    # Plotting
    plt.figure(figsize=(15, 5))
    
    # Plot 1: Streams by Key
    plt.subplot(1, 2, 1)
    sns.barplot(x=key_streams.index, y=key_streams.values)
    plt.title('Average Streams by Key')
    plt.xlabel('Key')
    plt.ylabel('Average Streams')
    plt.xticks(rotation=45)
    
    # Plot 2: Streams by Mode
    plt.subplot(1, 2, 2)
    sns.barplot(x=mode_streams.index, y=mode_streams.values)
    plt.title('Average Streams by Mode (Major/Minor)')
    plt.xlabel('Mode')
    plt.ylabel('Average Streams')
    
    plt.tight_layout()
    plt.show()
    
    # Statistical summary
    print("\nKey with highest average streams:", key_streams.index[0])
    print("Mode comparison:")
    print(mode_streams)

# 2. Analysis of Artists in Playlists and Charts
def analyze_artist_presence(df):
    print("\n=== Analysis of Artist Presence in Playlists and Charts ===")
    
    # Create a DataFrame with artist and their playlist/chart presence
    artist_metrics = df.groupby('artist(s)_name').agg({
        'in_spotify_playlists': 'sum',
        'in_spotify_charts': 'sum',
        'in_apple_playlists': 'sum',
        'streams': 'sum'
    }).reset_index()
    
    # Sort by total presence across all platforms
    artist_metrics['total_presence'] = (artist_metrics['in_spotify_playlists'] + 
                                      artist_metrics['in_spotify_charts'] + 
                                      artist_metrics['in_apple_playlists'])
    
    # Get top 10 artists by presence
    top_artists = artist_metrics.nlargest(10, 'total_presence')
    
    # Plotting
    plt.figure(figsize=(12, 6))
    
    # Create a stacked bar chart
    bottom = np.zeros(len(top_artists))
    
    for column in ['in_spotify_playlists', 'in_spotify_charts', 'in_apple_playlists']:
        plt.bar(top_artists['artist(s)_name'], top_artists[column], bottom=bottom, label=column)
        bottom += top_artists[column]
    
    plt.title('Top 10 Artists by Platform Presence')
    plt.xlabel('Artist')
    plt.ylabel('Total Presence')
    plt.xticks(rotation=45, ha='right')
    plt.legend()
    plt.tight_layout()
    plt.show()
    
    # Print detailed statistics
    print("\nTop 5 Artists by Platform Presence:")
    print(top_artists[['artist(s)_name', 'total_presence', 'streams']].head().to_string())

# 3. Correlation Analysis
def analyze_correlations(df):
    print("\n=== Correlation Analysis ===")
    
    # Calculate correlations between key metrics
    correlation_metrics = ['streams', 'in_spotify_playlists', 'in_spotify_charts', 
                         'in_apple_playlists', 'danceability_%', 'energy_%', 'valence_%']
    
    correlations = df[correlation_metrics].corr()
    
    # Plot correlation heatmap
    plt.figure(figsize=(10, 8))
    sns.heatmap(correlations, annot=True, cmap='coolwarm', center=0)
    plt.title('Correlation Heatmap of Key Metrics')
    plt.tight_layout()
    plt.show()

# Main execution
def main():
    # Load your DataFrame here with a different encoding
    try:
        # Try different encodings
        encodings = ['latin1', 'iso-8859-1', 'cp1252']
        df = None
        
        for encoding in encodings:
            try:
                df = pd.read_csv('spotify-2023.csv', encoding=encoding)
                print(f"Successfully loaded with {encoding} encoding")
                break
            except UnicodeDecodeError:
                continue
        
        if df is None:
            raise Exception("Could not read the file with any of the attempted encodings")
        
        # Clean and prepare data
        df['streams'] = pd.to_numeric(df['streams'], errors='coerce')
        df['in_spotify_playlists'] = pd.to_numeric(df['in_spotify_playlists'], errors='coerce')
        df['in_spotify_charts'] = pd.to_numeric(df['in_spotify_charts'], errors='coerce')
        df['in_apple_playlists'] = pd.to_numeric(df['in_apple_playlists'], errors='coerce')
        
        # Run analyses
        analyze_key_mode_patterns(df)
        analyze_artist_presence(df)
        analyze_correlations(df)
        
    except Exception as e:
        print(f"An error occurred: {str(e)}")

if __name__ == "__main__":
    main()
# Out:
# Successfully loaded with latin1 encoding
#
# === Analysis of Streams by Key and Mode ===
# Key with highest average streams: C#
# Mode comparison:
# mode
# Major    5.348328e+08
# Minor    4.859445e+08
# Name: streams, dtype: float64
#
# === Analysis of Artist Presence in Playlists and Charts ===
# Top 5 Artists by Platform Presence:
#     artist(s)_name  total_presence       streams
# 572     The Weeknd          145910  1.418555e+10
# 558   Taylor Swift          135312  1.405366e+10
# 159     Ed Sheeran          130300  1.390895e+10
# 223   Harry Styles          111952  1.160865e+10
# 171         Eminem           87958  6.183806e+09
#
# === Correlation Analysis ===

# %%
import pandas as pd
import numpy.ma as ma

# Assuming df is already defined in your environment
# Statistics for Streams
streams = pd.to_numeric(df['streams'], errors='coerce')  # Convert to numeric, replacing errors with NaN
streams_stats_df = pd.DataFrame({
    "Statistic": ["Mean", "Median", "Standard Deviation"],
    "Streams": [streams.mean(), streams.median(), streams.std()]
})

# Display streams statistics as DataFrame
print("Statistics for Streams:")
display(streams_stats_df)
print("\n")

# Distribution of released_year
year_dist_df = df['released_year'].value_counts().sort_index().reset_index()
year_dist_df.columns = ["Released Year", "Count"]

# Summary Statistics for Released Year
released_year_summary_df = df['released_year'].describe().to_frame(name="Released Year Stats").reset_index()
released_year_summary_df.columns = ["Statistic", "Value"]

# Display year distribution and summary statistics as DataFrames
print("Distribution of Released Year:")
display(year_dist_df)
print("\nSummary Statistics for Released Year:")
display(released_year_summary_df)
print("\n")

# Distribution of artist_count
artist_count_dist_df = df['artist_count'].value_counts().sort_index().reset_index()
artist_count_dist_df.columns = ["Artist Count", "Count"]

# Summary Statistics for Artist Count
artist_count_summary_df = df['artist_count'].describe().to_frame(name="Artist Count Stats").reset_index()
artist_count_summary_df.columns = ["Statistic", "Value"]

# Display artist count distribution and summary statistics as DataFrames
print("Distribution of Artist Count:")
display(artist_count_dist_df)
print("\nSummary Statistics for Artist Count:")
display(artist_count_summary_df)
# Out:
# Statistics for Streams:
#             Statistic       Streams
# 0                Mean  5.141374e+08
# 1              Median  2.905309e+08
# 2  Standard Deviation  5.668569e+08
# Distribution of Released Year:
#     Released Year  Count
# 0            1930      1
# 1            1942      1
# 2            1946      1
# 3            1950      1
# 4            1952      1
# 5            1957      2
# 6            1958      3
# 7            1959      2
# 8            1963      3
# 9            1968      1
# 10           1970      2
# 11           1971      1
# 12           1973      1
# 13           1975      2
# 14           1979      1
# 15           1982      2
# 16           1983      1
# 17           1984      4
# 18           1985      2
# 19           1986      2
# 20           1987      1
# 21           1991      2
# 22           1992      1
# 23           1994      1
# 24           1995      2
# 25           1996      1
# 26           1997      1
# 27           1998      1
# 28           1999      5
# 29           2000      4
# 30           2002      6
# 31           2003      2
# 32           2004      4
# 33           2005      1
# 34           2007      1
# 35           2008      2
# 36           2010      7
# 37           2011     10
# 38           2012     10
# 39           2013     13
# 40           2014     13
# 41           2015     11
# 42           2016     18
# 43           2017     23
# 44           2018     10
# 45           2019     36
# 46           2020     37
# 47           2021    119
# 48           2022    402
# 49           2023    175
# Summary Statistics for Released Year:
#   Statistic        Value
# 0     count   953.000000
# 1      mean  2018.238195
# 2       std    11.116218
# 3       min  1930.000000
# 4       25%  2020.000000
# 5       50%  2022.000000
# 6       75%  2022.000000
# 7       max  2023.000000
# Distribution of Artist Count:
#    Artist Count  Count
# 0             1    587
# 1             2    254
# 2             3     85
# 3             4     15
# 4             5      5
# 5             6      3
# 6             7      2
# 7             8      2
# Summary Statistics for Artist Count:
#   Statistic       Value
# 0     count  953.000000
# 1      mean    1.556139
# 2       std    0.893044
# 3       min    1.000000
# 4       25%    1.000000
# 5       50%    1.000000
# 6       75%    2.000000
# 7       max    8.000000

# %%
# Import pandas and numpy for numerical operations
import pandas as pd
import numpy.ma as ma

# Basic statistics for Streams
print("Statistics for Streams:")
print("-----------------------")
streams = pd.to_numeric(df['streams'], errors='coerce')  # Convert to numeric, replacing errors with NaN
print(f"Mean: {streams.mean():,.0f}")
print(f"Median: {streams.median():,.0f}")
print(f"Standard Deviation: {streams.std():,.0f}")
print("\n")

# Distribution of released_year
print("Distribution of Released Year:")
print("-----------------------")
year_dist = df['released_year'].value_counts().sort_index()
print(year_dist)
print("\nSummary Statistics for Released Year:")
print(df['released_year'].describe())
print("\n")

# Distribution of artist_count
print("Distribution of Artist Count:")
print("-----------------------")
artist_count_dist = df['artist_count'].value_counts().sort_index()
print(artist_count_dist)
print("\nSummary Statistics for Artist Count:")
print(df['artist_count'].describe())
# Out:
# Statistics for Streams:
# -----------------------
# Mean: 514,137,425
# Median: 290,530,915
# Standard Deviation: 566,856,949
#
#
# Distribution of Released Year:
# -----------------------
# released_year
# 1930      1
# 1942      1
# 1946      1
# 1950      1
# 1952      1
# 1957      2
# 1958      3
# 1959      2
# 1963      3
# 1968      1
# 1970      2
# 1971      1
# 1973      1
# 1975      2
# 1979      1
# 1982      2
# 1983      1
# 1984      4
# 1985      2
# 1986      2
# 1987      1
# 1991      2
# 1992      1
# 1994      1
# 1995      2
# 1996      1
# 1997      1
# 1998      1
# 1999      5
# 2000      4
# 2002      6
# 2003      2
# 2004      4
# 2005      1
# 2007      1
# 2008      2
# 2010      7
# 2011     10
# 2012     10
# 2013     13
# 2014     13
# 2015     11
# 2016     18
# 2017     23
# 2018     10
# 2019     36
# 2020     37
# 2021    119
# 2022    402
# 2023    175
# Name: count, dtype: int64
#
# Summary Statistics for Released Year:
# count     953.000000
# mean     2018.238195
# std        11.116218
# min      1930.000000
# 25%      2020.000000
# 50%      2022.000000
# 75%      2022.000000
# max      2023.000000
# Name: released_year, dtype: float64
#
#
# Distribution of Artist Count:
# -----------------------
# artist_count
# 1    587
# 2    254
# 3     85
# 4     15
# 5      5
# 6      3
# 7      2
# 8      2
# Name: count, dtype: int64
#
# Summary Statistics for Artist Count:
# count    953.000000
# mean       1.556139
# std        0.893044
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max        8.000000
# Name: artist_count, dtype: float64

# %%
# Sort the dataframe by streams in descending order and select the top 5 rows
top_5_streams = df.sort_values('streams', ascending=False).head(5)

# Display the results
print(top_5_streams[['track_name', 'artist(s)_name', 'streams']])
# Out:
#                                         track_name         artist(s)_name  \
# 55                                 Blinding Lights             The Weeknd
# 179                                   Shape of You             Ed Sheeran
# 86                               Someone You Loved          Lewis Capaldi
# 620                                   Dance Monkey            Tones and I
# 41   Sunflower - Spider-Man: Into the Spider-Verse  Post Malone, Swae Lee
#
#           streams
# 55   3.703895e+09
# 179  3.562544e+09
# 86   2.887242e+09
# 620  2.864792e+09
# 41   2.808097e+09

# %%
top_5_artists = df['artist(s)_name'].value_counts().head(5)

# Display the results
print("\nTop 5 Artists by Number of Tracks:")
print(top_5_artists)
# Out:
# Top 5 Artists by Number of Tracks:
# artist(s)_name
# Taylor Swift    34
# The Weeknd      22
# Bad Bunny       19
# SZA             19
# Harry Styles    17
# Name: count, dtype: int64

# %%
import pandas as pd
import numpy as np

# Load your DataFrame (assuming it's already loaded as df)
# df = pd.read_csv('your_file.csv')  # Example of loading a DataFrame

# Step 1: Identify the problematic row
problematic_row = df.loc[574]  # Access the row directly
print("Problematic Row:")
print(problematic_row)

# Step 2: Replace the invalid value with NaN
# You can also choose to drop the row instead
df.loc[574, 'streams'] = np.nan  # Replace with NaN

# Alternatively, if you want to drop the row:
# df = df.drop(index=574)

# Step 3: Convert the 'streams' column to numeric, coercing errors to NaN
df['streams'] = pd.to_numeric(df['streams'], errors='coerce')

# Optional: Check for any remaining NaN values in the 'streams' column
nan_count = df['streams'].isna().sum()
print(f"Number of NaN values in 'streams' column after cleaning: {nan_count}")

# Optional: If you want to drop all rows with NaN in 'streams'
# df = df.dropna(subset=['streams'])

# Now your DataFrame should be cleaned and ready for analysis
# Out:
# Problematic Row:
# track_name              Love Grows (Where My Rosemary Goes)
# artist(s)_name                            Edison Lighthouse
# artist_count                                              1
# released_year                                          1970
# released_month                                            1
# released_day                                              1
# in_spotify_playlists                                   2877
# in_spotify_charts                                         0
# streams                                                 NaN
# in_apple_playlists                                       16
# in_apple_charts                                           0
# in_deezer_playlists                                      54
# in_deezer_charts                                          0
# in_shazam_charts                                          0
# bpm                                                     110
# key                                                       A
# mode                                                  Major
# danceability_%                                           53
# valence_%                                                75
# energy_%                                                 69
# acousticness_%                                            7
# instrumentalness_%                                        0
# liveness_%                                               17
# speechiness_%                                             3
# Name: 574, dtype: object
# Number of NaN values in 'streams' column after cleaning: 1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Convert relevant columns to numeric, coercing errors to NaN
df['streams'] = pd.to_numeric(df['streams'], errors='coerce')
df['bpm'] = pd.to_numeric(df['bpm'], errors='coerce')
df['danceability_%'] = pd.to_numeric(df['danceability_%'], errors='coerce')
df['energy_%'] = pd.to_numeric(df['energy_%'], errors='coerce')
df['valence_%'] = pd.to_numeric(df['valence_%'], errors='coerce')
df['acousticness_%'] = pd.to_numeric(df['acousticness_%'], errors='coerce')
df['instrumentalness_%'] = pd.to_numeric(df['instrumentalness_%'], errors='coerce')
df['liveness_%'] = pd.to_numeric(df['liveness_%'], errors='coerce')
df['speechiness_%'] = pd.to_numeric(df['speechiness_%'], errors='coerce')

# Calculate correlation matrix and display it as a DataFrame
correlation_matrix = df[['streams', 'bpm', 'danceability_%', 'energy_%', 'valence_%', 
                         'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%']].corr()
correlation_matrix_df = correlation_matrix.reset_index().rename(columns={'index': 'Attribute'})

# Display correlation matrix as a DataFrame
print("Correlation Matrix:")
display(correlation_matrix_df)

# Plotting the correlation heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap of Streams and Musical Attributes')
plt.show()

# Scatter plots for streams vs musical attributes
attributes = ['bpm', 'danceability_%', 'energy_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%']
for attr in attributes:
    plt.figure(figsize=(8, 5))
    sns.scatterplot(data=df, x=attr, y='streams')
    plt.title(f'Scatter Plot: Streams vs {attr}')
    plt.xlabel(attr)
    plt.ylabel('Streams')
    plt.grid()
    plt.show()

# Calculate and display specific correlations as DataFrames
danceability_energy_corr = df['danceability_%'].corr(df['energy_%'])
valence_acousticness_corr = df['valence_%'].corr(df['acousticness_%'])
liveness_speechiness_corr = df['liveness_%'].corr(df['speechiness_%'])

# Create a DataFrame to display these specific correlations
specific_correlations_df = pd.DataFrame({
    "Correlation Pair": ["Danceability vs Energy", "Valence vs Acousticness", "Liveness vs Speechiness"],
    "Correlation Value": [danceability_energy_corr, valence_acousticness_corr, liveness_speechiness_corr]
})

# Display the specific correlations
print("Specific Correlations:")
display(specific_correlations_df)
# Out:
# Correlation Matrix:
#             Attribute   streams       bpm  danceability_%  energy_%  \
# 0             streams  1.000000 -0.002438       -0.105457 -0.026051
# 1                 bpm -0.002438  1.000000       -0.147095  0.025794
# 2      danceability_% -0.105457 -0.147095        1.000000  0.198095
# 3            energy_% -0.026051  0.025794        0.198095  1.000000
# 4           valence_% -0.040831  0.041195        0.408451  0.357612
# 5      acousticness_% -0.004485 -0.017694       -0.236165 -0.577344
# 6  instrumentalness_% -0.044902 -0.001195       -0.089138 -0.038547
# 7          liveness_% -0.048337 -0.000761       -0.077538  0.117302
# 8       speechiness_% -0.112333  0.039260        0.184977 -0.004846
#
#    valence_%  acousticness_%  instrumentalness_%  liveness_%  speechiness_%
# 0  -0.040831       -0.004485           -0.044902   -0.048337      -0.112333
# 1   0.041195       -0.017694           -0.001195   -0.000761       0.039260
# 2   0.408451       -0.236165           -0.089138   -0.077538       0.184977
# 3   0.357612       -0.577344           -0.038547    0.117302      -0.004846
# 4   1.000000       -0.081907           -0.132890    0.021278       0.041081
# 5  -0.081907        1.000000            0.042796   -0.050142      -0.022501
# 6  -0.132890        0.042796            1.000000   -0.045967      -0.083396
# 7   0.021278       -0.050142           -0.045967    1.000000      -0.022525
# 8   0.041081       -0.022501           -0.083396   -0.022525       1.000000
# Specific Correlations:
#           Correlation Pair  Correlation Value
# 0   Danceability vs Energy           0.198095
# 1  Valence vs Acousticness          -0.081907
# 2  Liveness vs Speechiness          -0.022525

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df is your DataFrame and it contains the relevant columns

# Convert relevant columns to numeric, coercing errors to NaN
df['streams'] = pd.to_numeric(df['streams'], errors='coerce')
df['bpm'] = pd.to_numeric(df['bpm'], errors='coerce')
df['danceability_%'] = pd.to_numeric(df['danceability_%'], errors='coerce')
df['energy_%'] = pd.to_numeric(df['energy_%'], errors='coerce')
df['valence_%'] = pd.to_numeric(df['valence_%'], errors='coerce')
df['acousticness_%'] = pd.to_numeric(df['acousticness_%'], errors='coerce')

# Calculate correlation matrix
correlation_matrix = df[['streams', 'bpm', 'danceability_%', 'energy_%', 'valence_%', 'acousticness_%']].corr()

# Display the correlation matrix
print("Correlation Matrix:")
print(correlation_matrix)

# Plotting the correlation heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap of Streams and Musical Attributes')
plt.show()

# Scatter plots for streams vs musical attributes
attributes = ['bpm', 'danceability_%', 'energy_%']
for attr in attributes:
    plt.figure(figsize=(8, 5))
    sns.scatterplot(data=df, x=attr, y='streams')
    plt.title(f'Scatter Plot: Streams vs {attr}')
    plt.xlabel(attr)
    plt.ylabel('Streams')
    plt.grid()
    plt.show()

# Correlation between danceability_% and energy_%
danceability_energy_corr = df['danceability_%'].corr(df['energy_%'])
print(f"Correlation between Danceability and Energy: {danceability_energy_corr:.2f}")

# Correlation between valence_% and acousticness_%
valence_acousticness_corr = df['valence_%'].corr(df['acousticness_%'])
print(f"Correlation between Valence and Acousticness: {valence_acousticness_corr:.2f}")
# Out:
# Correlation Matrix:
#                  streams       bpm  danceability_%  energy_%  valence_%  \
# streams         1.000000 -0.002438       -0.105457 -0.026051  -0.040831
# bpm            -0.002438  1.000000       -0.147095  0.025794   0.041195
# danceability_% -0.105457 -0.147095        1.000000  0.198095   0.408451
# energy_%       -0.026051  0.025794        0.198095  1.000000   0.357612
# valence_%      -0.040831  0.041195        0.408451  0.357612   1.000000
# acousticness_% -0.004485 -0.017694       -0.236165 -0.577344  -0.081907
#
#                 acousticness_%
# streams              -0.004485
# bpm                  -0.017694
# danceability_%       -0.236165
# energy_%             -0.577344
# valence_%            -0.081907
# acousticness_%        1.000000
# Correlation between Danceability and Energy: 0.20
# Correlation between Valence and Acousticness: -0.08

# %%
import pandas as pd
import numpy as np

# Sample data for demonstration (replace with actual data as needed)
data = {
    'streams': np.random.randint(1000, 5000, size=100),  # Replace with actual stream data
    'in_spotify_playlists': np.random.choice([0, 1], size=100),  # Random 0 or 1 indicating presence in playlists
    'in_spotify_charts': np.random.choice([0, 1], size=100),     # Random 0 or 1 for Spotify charts
    'in_apple_playlists': np.random.choice([0, 1], size=100)     # Random 0 or 1 for Apple playlists
}

# Create DataFrame
df = pd.DataFrame(data)

# Display the first few rows to verify
print(df.head())
# Out:
#    streams  in_spotify_playlists  in_spotify_charts  in_apple_playlists
# 0     1533                     0                  0                   1
# 1     1816                     0                  0                   1
# 2     2937                     0                  0                   1
# 3     1511                     1                  1                   0
# 4     3875                     1                  1                   0

# %%
import pandas as pd
import numpy as np

# Assuming you've already calculated the correlation
correlation_with_streams = df[['streams', 'in_spotify_playlists', 'in_spotify_charts', 'in_apple_playlists']].corr()

# Convert correlation matrix to DataFrame
correlation_df = pd.DataFrame(correlation_with_streams)

# Round the values to 4 decimal places
correlation_df = correlation_df.round(4)

# Reset the index to make 'Variable' a column
correlation_df = correlation_df.reset_index()
correlation_df = correlation_df.rename(columns={'index': 'Variable'})

# Display the DataFrame
print("Correlation with Streams:")
print(correlation_df.to_string(index=False))

# Determine which platform favors the most popular tracks
most_popular_platform = correlation_df['streams'].drop(correlation_df[correlation_df['Variable'] == 'streams'].index).idxmax()
most_popular_value = correlation_df.loc[most_popular_platform, 'streams']

print(f"\nThe platform that seems to favor the most popular tracks is: {correlation_df.loc[most_popular_platform, 'Variable']} with a correlation of {most_popular_value:.4f}")
# Out:
# Correlation with Streams:
#             Variable  streams  in_spotify_playlists  in_spotify_charts  in_apple_playlists
#              streams   1.0000                0.7898             0.2458              0.7721
# in_spotify_playlists   0.7898                1.0000             0.1643              0.7083
#    in_spotify_charts   0.2458                0.1643             1.0000              0.2334
#   in_apple_playlists   0.7721                0.7083             0.2334              1.0000
#
# The platform that seems to favor the most popular tracks is: in_spotify_playlists with a correlation of 0.7898
